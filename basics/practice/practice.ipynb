# %% [markdown]
# LEVEL-1

# %%
# 1. Take a number as input and print whether it is even or odd.
def num_type(num):
    # num= int(input("enter a number: "))
    if num%2==0:
        print("number is even")
    else:
        print("number is odd")

#diffrent ways to call this function
num_type(101)
num_type(102)
x = int(input("Enter a number: "))
num_type(x)
numbers = [1, 2, 3, 4]

for n in numbers:
    num_type(n)
# Out:
# number is odd
# number is even
# number is even
# number is odd
# number is even
# number is odd
# number is even

# %%
# 2. Swap two variables without using a third variable
def swap_nums(num1,num2):
# Out:
# 7 5

# %%
# 4. Take a string and print it in reverse using slicing.
